# %%
import random

class Character:
    def __init__(self, name, level, health, attack, defense):
        self.name = name
        self.level = level
        self.health = health
        self.attack = attack
        self.defense = defense

    def is_alive(self):
        return self.health > 0

    def take_damage(self, damage):
        get_damage = damage - self.defense
        if get_damage < 0:
            get_damage = 0
        self.health -= get_damage
        if self.health < 0:
            self.health = 0
        print(f"👿{self.name} {get_damage}만큼 얻어 맞았습니다. (남은 체력: {self.health})")

    def attack_target(self, target):
        damage = random.randint(1, self.attack)
        print(f"⚡{self.name} {target.name} 폭행하여 {damage}만큼 아파합니다")
        target.take_damage(damage)

class Player(Character):
    def __init__(self, name):
        super().__init__(name, level = 1, health = 100, attack = 25, defense = 5)
        self.ex = 0

    def gain_experience(self, exp):
        self.ex += exp
        print(f"\n   🎁 {self.name} 경험치 {exp}만큼 얻음 (현재 경험치: {self.ex})")
        self.level_up()

    def level_up(self):
        while self.ex >= 50:
            self.level += 1
            self.attack += 10
            self.defense += 5
            self.ex -= 50
            print(f"   🎉 {self.name} 레벨업! (레벨: {self.level}, 공격력: {self.attack}, 방어력: {self.defense})")

class Monster(Character):
    def __init__(self, name, level):
        health = random.randint(10, 30) * level
        attack = random.randint(5, 20) * level
        defense = random.randint(1, 5) * level

        super().__init__(name, level, health, attack, defense)

def Battle(player, monster):
    print(f"\n ⚔️  {player.name} vs {monster.name} ⚔️")

    while player.is_alive() and monster.is_alive():
        player.attack_target(monster)
        if monster.is_alive():
            monster.attack_target(player)

    if player.is_alive():
        print("\n   🏆 전투 승리!!🏆")
        exp_gain = monster.level * 20
        player.gain_experience(exp_gain)
    else:
        print("\n 🔪🔪🔪🔪전투 패배..🔪🔪🔪🔪")


def Main():
    monster_dict = {'슬라임': 1, '고블린': 2, '오크': 3}
    player_name = input("플레이어 이름을 입력하세요: ")
    player = Player(player_name)

    for monster_name, monster_level in monster_dict.items():
        monster = Monster(monster_name, monster_level)

        Battle(player, monster)  # 전투 시작!

        if not player.is_alive():
            print("\n 💀💀💀💀  게임오버  💀💀💀💀")
            return  # 플레이어가 죽으면 게임 종료

    print(" \n ❤🧡💛💚💙💜🤎  게임 클리어  🤎💜💙💚💛🧡❤ ")

Main()
# Out:
# 플레이어 이름을 입력하세요: 히어로
#
#  ⚔️  히어로 vs 슬라임 ⚔️
# ⚡히어로 슬라임 폭행하여 4만큼 아파합니다
# 👿슬라임 2만큼 얻어 맞았습니다. (남은 체력: 21)
# ⚡슬라임 히어로 폭행하여 11만큼 아파합니다
# 👿히어로 6만큼 얻어 맞았습니다. (남은 체력: 94)
# ⚡히어로 슬라임 폭행하여 14만큼 아파합니다
# 👿슬라임 12만큼 얻어 맞았습니다. (남은 체력: 9)
# ⚡슬라임 히어로 폭행하여 6만큼 아파합니다
# 👿히어로 1만큼 얻어 맞았습니다. (남은 체력: 93)
# ⚡히어로 슬라임 폭행하여 22만큼 아파합니다
# 👿슬라임 20만큼 얻어 맞았습니다. (남은 체력: 0)
#
#    🏆 전투 승리!!🏆
#
#    🎁 히어로 경험치 20만큼 얻음 (현재 경험치: 20)
#
#  ⚔️  히어로 vs 고블린 ⚔️
# ⚡히어로 고블린 폭행하여 6만큼 아파합니다
# 👿고블린 4만큼 얻어 맞았습니다. (남은 체력: 24)
# ⚡고블린 히어로 폭행하여 2만큼 아파합니다
# 👿히어로 0만큼 얻어 맞았습니다. (남은 체력: 93)
# ⚡히어로 고블린 폭행하여 9만큼 아파합니다
# 👿고블린 7만큼 얻어 맞았습니다. (남은 체력: 17)
# ⚡고블린 히어로 폭행하여 1만큼 아파합니다
# 👿히어로 0만큼 얻어 맞았습니다. (남은 체력: 93)
# ⚡히어로 고블린 폭행하여 21만큼 아파합니다
# 👿고블린 19만큼 얻어 맞았습니다. (남은 체력: 0)
#
#    🏆 전투 승리!!🏆
#
#    🎁 히어로 경험치 40만큼 얻음 (현재 경험치: 60)
#    🎉 히어로 레벨업! (레벨: 2, 공격력: 35, 방어력: 10)
#
#  ⚔️  히어로 vs 오크 ⚔️
# ⚡히어로 오크 폭행하여 6만큼 아파합니다
# 👿오크 0만큼 얻어 맞았습니다. (남은 체력: 51)
# ⚡오크 히어로 폭행하여 16만큼 아파합니다
# 👿히어로 6만큼 얻어 맞았습니다. (남은 체력: 87)
# ⚡히어로 오크 폭행하여 34만큼 아파합니다
# 👿오크 22만큼 얻어 맞았습니다. (남은 체력: 29)
# ⚡오크 히어로 폭행하여 17만큼 아파합니다
# 👿히어로 7만큼 얻어 맞았습니다. (남은 체력: 80)
# ⚡히어로 오크 폭행하여 23만큼 아파합니다
# 👿오크 11만큼 얻어 맞았습니다. (남은 체력: 18)
# ⚡오크 히어로 폭행하여 3만큼 아파합니다
# 👿히어로 0만큼 얻어 맞았습니다. (남은 체력: 80)
# ⚡히어로 오크 폭행하여 8만큼 아파합니다
# 👿오크 0만큼 얻어 맞았습니다. (남은 체력: 18)
# ⚡오크 히어로 폭행하여 21만큼 아파합니다
# 👿히어로 11만큼 얻어 맞았습니다. (남은 체력: 69)
# ⚡히어로 오크 폭행하여 18만큼 아파합니다
# 👿오크 6만큼 얻어 맞았습니다. (남은 체력: 12)
# ⚡오크 히어로 폭행하여 15만큼 아파합니다
# 👿히어로 5만큼 얻어 맞았습니다. (남은 체력: 64)
# ⚡히어로 오크 폭행하여 19만큼 아파합니다
# 👿오크 7만큼 얻어 맞았습니다. (남은 체력: 5)
# ⚡오크 히어로 폭행하여 2만큼 아파합니다
# 👿히어로 0만큼 얻어 맞았습니다. (남은 체력: 64)
# ⚡히어로 오크 폭행하여 14만큼 아파합니다
# 👿오크 2만큼 얻어 맞았습니다. (남은 체력: 3)
# ⚡오크 히어로 폭행하여 6만큼 아파합니다
# 👿히어로 0만큼 얻어 맞았습니다. (남은 체력: 64)
# ⚡히어로 오크 폭행하여 4만큼 아파합니다
# 👿오크 0만큼 얻어 맞았습니다. (남은 체력: 3)
# ⚡오크 히어로 폭행하여 5만큼 아파합니다
# 👿히어로 0만큼 얻어 맞았습니다. (남은 체력: 64)
# ⚡히어로 오크 폭행하여 24만큼 아파합니다
# 👿오크 12만큼 얻어 맞았습니다. (남은 체력: 0)
#
#    🏆 전투 승리!!🏆
#
#    🎁 히어로 경험치 60만큼 얻음 (현재 경험치: 70)
#    🎉 히어로 레벨업! (레벨: 3, 공격력: 45, 방어력: 15)
#
#  ❤🧡💛💚💙💜🤎  게임 클리어  🤎💜💙💚💛🧡❤
